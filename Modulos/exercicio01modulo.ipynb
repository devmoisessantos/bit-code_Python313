# %%
import matplotlib.pyplot as plt
import matplotlib.image as imgplt

# %%
img = imgplt.imread('exercicio01.jpg')
plt.imshow(img)
plt.axis('off')
plt.show()

# %%
# This is a module:

"""Modulo para trabalhar com Strings."""

def inverterStr(string):
    return f'O texto: {string} invertido é: {string[::-1]}'

texto = inverterStr('JAINE')

# %%
print(texto)
# Out:
# O texto: JAINE invertido é: ENIAJ

# %%
def retornarStrPares(string):
    string_pares = [
            f"{indice}: {letra}  "
            for indice, letra in enumerate(string) 
            if indice % 2 == 0
    ]
    mensagem = (
            f"As letras pares do texto = '{string}' é: {' '.join(string_pares)}"
        )
    return mensagem

# %%
string = retornarStrPares('MAGALHAES')
print(string)
# Out:
# As letras pares do texto = 'MAGALHAES' é: 0: M   2: G   4: L   6: A   8: S

# %%
def retornarStrPares(string):
    string_impares = [
            f"{indice}: {letra}  "
            for indice, letra in enumerate(string) 
            if indice % 2 != 0
    ]
    mensagem = (
            f"As letras pares do texto = '{string}' é: {' '.join(string_impares)}"
        )
    return mensagem

# %%
string = retornarStrPares('MAGALHAES')
print(string)
# Out:
# As letras pares do texto = 'MAGALHAES' é: 1: A   3: A   5: H   7: E
